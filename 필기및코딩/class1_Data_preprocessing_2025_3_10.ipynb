# %%
name = str(input("이름: "))
age = int(input("나이: "))

print(f"이름:{name}, 나이:{age}")
# Out:
# 이름: 이혜준
# 나이: 24
# 이름:이혜준, 나이:24

# %%
a = [1,2,3]
b = [2,4,5]
c = a + b
print(c)
# Out:
# [1, 2, 3, 2, 4, 5]

# %%
A = [10, 5, 7, 9, 11, "안녕"]
print(A[3])
# Out:
# 9

# %%
import pandas as pd

indexName = ["국어점수", "수학점수", "영어점수 "]
Exam = pd.DataFrame([[80,70,50,40,50,60], [50,60,70,60,80,90,], [70,80,70,20,80,70,]], index = indexName)
print(Exam)
# Out:
#        0   1   2   3   4   5
# 국어점수  80  70  50  40  50  60
# 수학점수  50  60  70  60  80  90
# 영어점수  70  80  70  20  80  70

# %%
for i in range(1,10):
  print(f"--------{i}-------------")
  for j in range(1,10):
    print(f"구구단 : {i}X{j}={i*j}입니다.")
# Out:
# --------1-------------
# 구구단 : 1X1=1입니다.
# 구구단 : 1X2=2입니다.
# 구구단 : 1X3=3입니다.
# 구구단 : 1X4=4입니다.
# 구구단 : 1X5=5입니다.
# 구구단 : 1X6=6입니다.
# 구구단 : 1X7=7입니다.
# 구구단 : 1X8=8입니다.
# 구구단 : 1X9=9입니다.
# --------2-------------
# 구구단 : 2X1=2입니다.
# 구구단 : 2X2=4입니다.
# 구구단 : 2X3=6입니다.
# 구구단 : 2X4=8입니다.
# 구구단 : 2X5=10입니다.
# 구구단 : 2X6=12입니다.
# 구구단 : 2X7=14입니다.
# 구구단 : 2X8=16입니다.
# 구구단 : 2X9=18입니다.
# --------3-------------
# 구구단 : 3X1=3입니다.
# 구구단 : 3X2=6입니다.
# 구구단 : 3X3=9입니다.
# 구구단 : 3X4=12입니다.
# 구구단 : 3X5=15입니다.
# 구구단 : 3X6=18입니다.
# 구구단 : 3X7=21입니다.
# 구구단 : 3X8=24입니다.
# 구구단 : 3X9=27입니다.
# --------4-------------
# 구구단 : 4X1=4입니다.
# 구구단 : 4X2=8입니다.
# 구구단 : 4X3=12입니다.
# 구구단 : 4X4=16입니다.
# 구구단 : 4X5=20입니다.
# 구구단 : 4X6=24입니다.
# 구구단 : 4X7=28입니다.
# 구구단 : 4X8=32입니다.
# 구구단 : 4X9=36입니다.
# --------5-------------
# 구구단 : 5X1=5입니다.
# 구구단 : 5X2=10입니다.
# 구구단 : 5X3=15입니다.
# 구구단 : 5X4=20입니다.
# 구구단 : 5X5=25입니다.
# 구구단 : 5X6=30입니다.
# 구구단 : 5X7=35입니다.
# 구구단 : 5X8=40입니다.
# 구구단 : 5X9=45입니다.
# --------6-------------
# ...

# %%
exam=[60,80,95,69,90,81,80,69,79,66,70,90,96]
newlist = list(exam)
print(newlist)

for i in range(len(newlist)):
  print(f"당신의 성적은 {i}이므로 점수는 {}입니다")
# Out:
# list

# %%
# 피보나치 수열

num=0

def fibo (a, b):
    print(f"i의 값 : {a}, 합계 : {a+b}")
    num = a+b
    return num

while(1):
  fibo(num,num+1)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# i의 값 : 0, 합계 : 1
# ...

# %%
print("주문이요~")
order = int(input("보유 금액: "))
print(order)
if order >= 10000:
  print("구매가능")
else:
  print("구매 불가능")
# Out:
# 주문이요~
# 보유 금액: 10000
# 10000
# 구매가능
